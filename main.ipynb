# %%
from newspaper import Article
url = 'https://rzn.aif.ru/incidents/skoro_vernetsya_v_ryazani_tretiy_mesyac_ishchut_propavshuyu_elenu_loginovu'
my_article = Article(url, language='ru')
my_article.download()
